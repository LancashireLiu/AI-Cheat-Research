# %% [markdown]
# # TimeGAN Tutorial
#
# ## Time-series Generative Adversarial Networks
#
# - Paper: Jinsung Yoon, Daniel Jarrett, Mihaela van der Schaar, "Time-series Generative Adversarial Networks," Neural Information Processing Systems (NeurIPS), 2019.
#
# - Paper link: https://papers.nips.cc/paper/8789-time-series-generative-adversarial-networks
#
# - Last updated Date: April 24th 2020
#
# - Code author: Jinsung Yoon (jsyoon0823@gmail.com)
#
# This notebook describes the user-guide of a time-series synthetic data generation application using timeGAN framework. We use Stock, Energy, and Sine dataset as examples.
#
# ### Prerequisite
# Clone https://github.com/jsyoon0823/timeGAN.git to the current directory.

# %% [markdown]
# ## Necessary packages and functions call
#
# - timegan: Synthetic time-series data generation module
# - data_loading: 2 real datasets and 1 synthetic datasets loading and preprocessing
# - metrics:
#     - discriminative_metrics: classify real data from synthetic data
#     - predictive_metrics: train on synthetic, test on real
#     - visualization: PCA and tSNE analyses

# %%
## Necessary packages
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import warnings
warnings.filterwarnings("ignore")
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import tensorflow as tf

# 1. TimeGAN model
from timegan import timegan
# 2. Data loading
from data_loading import real_data_loading, sine_data_generation
# 3. Metrics
from metrics.discriminative_metrics import discriminative_score_metrics
from metrics.predictive_metrics import predictive_score_metrics
from metrics.visualization_metrics import visualization
# Out:
# C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\sklearn\linear_model\least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\sklearn\linear_model\least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\sklearn\linear_model\least_angle.py:284: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_Gram=True, verbose=0,
# C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\sklearn\linear_model\least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\sklearn\linear_model\least_angle.py:1101: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\sklearn\linear_model\least_angle.py:1127: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\sklearn\linear_model\least_angle.py:1362: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\sklearn\linear_model\least_angle.py:1602: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\sklearn\linear_model\least_angle.py:1738: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\sklearn\decomposition\online_lda.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps

# %% [markdown]
# ## Data Loading
#
# Load original dataset and preprocess the loaded data.
#
# - data_name: stock, energy, or sine
# - seq_len: sequence length of the time-series data

# %%
## Data loading
data_name = 'stock'
seq_len = 1000

if data_name in ['stock', 'energy']:
  ori_data = real_data_loading(data_name, seq_len)
elif data_name == 'sine':
  # Set number of samples and its dimensions
  no, dim = 10000, 5
  ori_data = sine_data_generation(no, seq_len, dim)
    
print(data_name + ' dataset is ready.')
# Out:
# stock dataset is ready.

# %% [markdown]
# ## Set network parameters
#
# TimeGAN network parameters should be optimized for different datasets.
#
# - module: gru, lstm, or lstmLN
# - hidden_dim: hidden dimensions
# - num_layer: number of layers
# - iteration: number of training iterations
# - batch_size: the number of samples in each batch

# %%
## Newtork parameters
parameters = dict()

parameters['module'] = 'gru' 
parameters['hidden_dim'] = 12
parameters['num_layer'] = 3
parameters['iterations'] = 8000
parameters['batch_size'] = 128

# %% [markdown]
# ## Run TimeGAN for synthetic time-series data generation
#
# TimeGAN uses the original data and network parameters to return the generated synthetic data.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd  # 添加这行代码来导入 pandas 库
from utils import extract_time, rnn_cell, random_generator, batch_generator

# Run TimeGAN
generated_data = timegan(ori_data, parameters)   
print('Finish Synthetic Data Generation')
generated_data = np.round(generated_data).astype(int)
dim = 2
# Save generated data
generated_data_array = np.array(generated_data)
np.save('generated_data.npy', generated_data_array)  # Save as .npy file
pd.DataFrame(generated_data_array.reshape(-1, dim)).to_csv('generated_data.csv', index=False)  # Save as .csv file

metric_iteration = 5

discriminative_score = list()
for _ in range(metric_iteration):
  temp_disc = discriminative_score_metrics(ori_data, generated_data)
  discriminative_score.append(temp_disc)

print('Discriminative score: ' + str(np.round(np.mean(discriminative_score), 4)))

predictive_score = list()
for tt in range(metric_iteration):
  temp_pred = predictive_score_metrics(ori_data, generated_data)
  predictive_score.append(temp_pred)   
    
print('Predictive score: ' + str(np.round(np.mean(predictive_score), 4)))

visualization(ori_data, generated_data, 'pca')
visualization(ori_data, generated_data, 'tsne')
# Out:
# WARNING:tensorflow:From C:\Users\Admin\Documents\WeChat Files\wxid_epckp5jbazzj22\FileStorage\File\2024-05\TimeGAN\TimeGAN\timegan.py:38: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Documents\WeChat Files\wxid_epckp5jbazzj22\FileStorage\File\2024-05\TimeGAN\TimeGAN\timegan.py:80: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Documents\WeChat Files\wxid_epckp5jbazzj22\FileStorage\File\2024-05\TimeGAN\TimeGAN\timegan.py:94: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Documents\WeChat Files\wxid_epckp5jbazzj22\FileStorage\File\2024-05\TimeGAN\TimeGAN\timegan.py:94: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Documents\WeChat Files\wxid_epckp5jbazzj22\FileStorage\File\2024-05\TimeGAN\TimeGAN\utils.py:95: GRUCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.GRUCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From C:\Users\Admin\Documents\WeChat Files\wxid_epckp5jbazzj22\FileStorage\File\2024-05\TimeGAN\TimeGAN\timegan.py:95: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From C:\Users\Admin\Documents\WeChat Files\wxid_epckp5jbazzj22\FileStorage\File\2024-05\TimeGAN\TimeGAN\timegan.py:96: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:559: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:565: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:575: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\tensorflow_core\python\ops\rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\tensorflow_core\contrib\layers\python\layers\layers.py:1866: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\Users\Admin\Documents\WeChat Files\wxid_epckp5jbazzj22\FileStorage\File\2024-05\TimeGAN\TimeGAN\timegan.py:182: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Documents\WeChat Files\wxid_epckp5jbazzj22\FileStorage\File\2024-05\TimeGAN\TimeGAN\timegan.py:189: The name tf.losses.sigmoid_cross_entropy is deprecated. Please use tf.compat.v1.losses.sigmoid_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Documents\WeChat Files\wxid_epckp5jbazzj22\FileStorage\File\2024-05\TimeGAN\TimeGAN\timegan.py:200: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Documents\WeChat Files\wxid_epckp5jbazzj22\FileStorage\File\2024-05\TimeGAN\TimeGAN\timegan.py:217: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Documents\WeChat Files\wxid_epckp5jbazzj22\FileStorage\File\2024-05\TimeGAN\TimeGAN\timegan.py:224: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Documents\WeChat Files\wxid_epckp5jbazzj22\FileStorage\File\2024-05\TimeGAN\TimeGAN\timegan.py:225: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# Start Embedding Network Training
# step: 0/3500, e_loss: 0.2427
# step: 10/3500, e_loss: 0.2228
# step: 20/3500, e_loss: 0.2206
# step: 30/3500, e_loss: 0.1965
# step: 40/3500, e_loss: 0.1751
# step: 50/3500, e_loss: 0.1677
# step: 60/3500, e_loss: 0.1629
# step: 70/3500, e_loss: 0.1584
# step: 80/3500, e_loss: 0.1548
# step: 90/3500, e_loss: 0.1499
# step: 100/3500, e_loss: 0.1399
# step: 110/3500, e_loss: 0.0965
# step: 120/3500, e_loss: 0.0744
# step: 130/3500, e_loss: 0.0624
# step: 140/3500, e_loss: 0.0567
# step: 150/3500, e_loss: 0.0518
# step: 160/3500, e_loss: 0.0481
# step: 170/3500, e_loss: 0.0447
# step: 180/3500, e_loss: 0.042
# step: 190/3500, e_loss: 0.0397
# step: 200/3500, e_loss: 0.0368
# step: 210/3500, e_loss: 0.0357
# step: 220/3500, e_loss: 0.0338
# step: 230/3500, e_loss: 0.0325
# step: 240/3500, e_loss: 0.0308
# step: 250/3500, e_loss: 0.0305
# step: 260/3500, e_loss: 0.0285
# step: 270/3500, e_loss: 0.0272
# step: 280/3500, e_loss: 0.0282
# step: 290/3500, e_loss: 0.0267
# step: 300/3500, e_loss: 0.0252
# step: 310/3500, e_loss: 0.0243
# step: 320/3500, e_loss: 0.024
# step: 330/3500, e_loss: 0.023
# step: 340/3500, e_loss: 0.0226
# step: 350/3500, e_loss: 0.0219
# step: 360/3500, e_loss: 0.0223
# step: 370/3500, e_loss: 0.0219
# step: 380/3500, e_loss: 0.0213
# step: 390/3500, e_loss: 0.0203
# step: 400/3500, e_loss: 0.0196
# step: 410/3500, e_loss: 0.0199
# step: 420/3500, e_loss: 0.0189
# step: 430/3500, e_loss: 0.0187
# step: 440/3500, e_loss: 0.0183
# step: 450/3500, e_loss: 0.0181
# step: 460/3500, e_loss: 0.0177
# step: 470/3500, e_loss: 0.0178
# step: 480/3500, e_loss: 0.0178
# step: 490/3500, e_loss: 0.0173
# step: 500/3500, e_loss: 0.017
# step: 510/3500, e_loss: 0.0161
# step: 520/3500, e_loss: 0.0167
# step: 530/3500, e_loss: 0.0161
# step: 540/3500, e_loss: 0.0156
# step: 550/3500, e_loss: 0.0152
# step: 560/3500, e_loss: 0.0151
# step: 570/3500, e_loss: 0.0156
# step: 580/3500, e_loss: 0.0147
# step: 590/3500, e_loss: 0.0146
# step: 600/3500, e_loss: 0.0146
# step: 610/3500, e_loss: 0.0148
# step: 620/3500, e_loss: 0.0146
# step: 630/3500, e_loss: 0.0139
# step: 640/3500, e_loss: 0.014
# step: 650/3500, e_loss: 0.0141
# step: 660/3500, e_loss: 0.014
# step: 670/3500, e_loss: 0.0142
# step: 680/3500, e_loss: 0.0131
# step: 690/3500, e_loss: 0.0135
# step: 700/3500, e_loss: 0.0137
# step: 710/3500, e_loss: 0.0131
# step: 720/3500, e_loss: 0.0136
# step: 730/3500, e_loss: 0.0135
# step: 740/3500, e_loss: 0.0125
# step: 750/3500, e_loss: 0.0134
# step: 760/3500, e_loss: 0.0123
# step: 770/3500, e_loss: 0.0126
# step: 780/3500, e_loss: 0.0121
# step: 790/3500, e_loss: 0.0119
# step: 800/3500, e_loss: 0.0118
# step: 810/3500, e_loss: 0.0117
# step: 820/3500, e_loss: 0.0122
# step: 830/3500, e_loss: 0.012
# step: 840/3500, e_loss: 0.0115
# step: 850/3500, e_loss: 0.0112
# step: 860/3500, e_loss: 0.0115
# step: 870/3500, e_loss: 0.0114
# step: 880/3500, e_loss: 0.0115
# step: 890/3500, e_loss: 0.011
# step: 900/3500, e_loss: 0.011
# step: 910/3500, e_loss: 0.0115
# step: 920/3500, e_loss: 0.0113
# step: 930/3500, e_loss: 0.011
# step: 940/3500, e_loss: 0.0109
# step: 950/3500, e_loss: 0.0106
# step: 960/3500, e_loss: 0.0105
# step: 970/3500, e_loss: 0.0109
# step: 980/3500, e_loss: 0.0108
# step: 990/3500, e_loss: 0.0104
# step: 1000/3500, e_loss: 0.0103
# step: 1010/3500, e_loss: 0.0106
# step: 1020/3500, e_loss: 0.0109
# step: 1030/3500, e_loss: 0.01
# step: 1040/3500, e_loss: 0.0105
# step: 1050/3500, e_loss: 0.0106
# step: 1060/3500, e_loss: 0.0106
# step: 1070/3500, e_loss: 0.0102
# step: 1080/3500, e_loss: 0.01
# step: 1090/3500, e_loss: 0.0098
# step: 1100/3500, e_loss: 0.01
# step: 1110/3500, e_loss: 0.0101
# step: 1120/3500, e_loss: 0.0096
# step: 1130/3500, e_loss: 0.0099
# step: 1140/3500, e_loss: 0.0097
# step: 1150/3500, e_loss: 0.0097
# step: 1160/3500, e_loss: 0.0094
# step: 1170/3500, e_loss: 0.0097
# step: 1180/3500, e_loss: 0.0096
# step: 1190/3500, e_loss: 0.0096
# step: 1200/3500, e_loss: 0.0095
# step: 1210/3500, e_loss: 0.0092
# step: 1220/3500, e_loss: 0.0091
# step: 1230/3500, e_loss: 0.0096
# step: 1240/3500, e_loss: 0.0093
# step: 1250/3500, e_loss: 0.0093
# step: 1260/3500, e_loss: 0.009
# step: 1270/3500, e_loss: 0.0089
# step: 1280/3500, e_loss: 0.0091
# step: 1290/3500, e_loss: 0.0084
# step: 1300/3500, e_loss: 0.0087
# step: 1310/3500, e_loss: 0.0087
# step: 1320/3500, e_loss: 0.0086
# step: 1330/3500, e_loss: 0.0084
# step: 1340/3500, e_loss: 0.0092
# step: 1350/3500, e_loss: 0.009
# step: 1360/3500, e_loss: 0.0084
# step: 1370/3500, e_loss: 0.0082
# step: 1380/3500, e_loss: 0.0084
# step: 1390/3500, e_loss: 0.0087
# step: 1400/3500, e_loss: 0.0088
# step: 1410/3500, e_loss: 0.0083
# step: 1420/3500, e_loss: 0.0081
# step: 1430/3500, e_loss: 0.008
# step: 1440/3500, e_loss: 0.0083
# step: 1450/3500, e_loss: 0.0081
# step: 1460/3500, e_loss: 0.008
# step: 1470/3500, e_loss: 0.0081
# step: 1480/3500, e_loss: 0.0081
# step: 1490/3500, e_loss: 0.0078
# step: 1500/3500, e_loss: 0.008
# step: 1510/3500, e_loss: 0.008
# step: 1520/3500, e_loss: 0.0077
# step: 1530/3500, e_loss: 0.0079
# step: 1540/3500, e_loss: 0.0076
# step: 1550/3500, e_loss: 0.0075
# step: 1560/3500, e_loss: 0.0079
# step: 1570/3500, e_loss: 0.0074
# step: 1580/3500, e_loss: 0.0077
# step: 1590/3500, e_loss: 0.0076
# step: 1600/3500, e_loss: 0.0071
# step: 1610/3500, e_loss: 0.007
# step: 1620/3500, e_loss: 0.0068
# step: 1630/3500, e_loss: 0.0075
# step: 1640/3500, e_loss: 0.0071
# step: 1650/3500, e_loss: 0.0072
# step: 1660/3500, e_loss: 0.0073
# step: 1670/3500, e_loss: 0.0072
# step: 1680/3500, e_loss: 0.0071
# step: 1690/3500, e_loss: 0.007
# step: 1700/3500, e_loss: 0.0072
# step: 1710/3500, e_loss: 0.0069
# step: 1720/3500, e_loss: 0.0069
# step: 1730/3500, e_loss: 0.0069
# step: 1740/3500, e_loss: 0.0068
# step: 1750/3500, e_loss: 0.0069
# step: 1760/3500, e_loss: 0.0065
# step: 1770/3500, e_loss: 0.0069
# step: 1780/3500, e_loss: 0.0067
# step: 1790/3500, e_loss: 0.0069
# step: 1800/3500, e_loss: 0.0065
# step: 1810/3500, e_loss: 0.0068
# step: 1820/3500, e_loss: 0.0066
# step: 1830/3500, e_loss: 0.0068
# step: 1840/3500, e_loss: 0.0066
# step: 1850/3500, e_loss: 0.0067
# step: 1860/3500, e_loss: 0.0065
# step: 1870/3500, e_loss: 0.0066
# step: 1880/3500, e_loss: 0.0063
# step: 1890/3500, e_loss: 0.0062
# step: 1900/3500, e_loss: 0.0064
# step: 1910/3500, e_loss: 0.0063
# step: 1920/3500, e_loss: 0.0063
# step: 1930/3500, e_loss: 0.0064
# step: 1940/3500, e_loss: 0.0061
# step: 1950/3500, e_loss: 0.0063
# step: 1960/3500, e_loss: 0.006
# step: 1970/3500, e_loss: 0.0061
# step: 1980/3500, e_loss: 0.0061
# step: 1990/3500, e_loss: 0.0061
# step: 2000/3500, e_loss: 0.006
# step: 2010/3500, e_loss: 0.0059
# step: 2020/3500, e_loss: 0.006
# step: 2030/3500, e_loss: 0.006
# step: 2040/3500, e_loss: 0.0058
# step: 2050/3500, e_loss: 0.0059
# step: 2060/3500, e_loss: 0.0056
# step: 2070/3500, e_loss: 0.006
# step: 2080/3500, e_loss: 0.0057
# step: 2090/3500, e_loss: 0.0058
# step: 2100/3500, e_loss: 0.006
# step: 2110/3500, e_loss: 0.0058
# step: 2120/3500, e_loss: 0.0057
# step: 2130/3500, e_loss: 0.0056
# step: 2140/3500, e_loss: 0.0057
# step: 2150/3500, e_loss: 0.0061
# step: 2160/3500, e_loss: 0.0055
# step: 2170/3500, e_loss: 0.0055
# step: 2180/3500, e_loss: 0.0054
# step: 2190/3500, e_loss: 0.0056
# step: 2200/3500, e_loss: 0.0055
# step: 2210/3500, e_loss: 0.0053
# step: 2220/3500, e_loss: 0.0055
# step: 2230/3500, e_loss: 0.0056
# step: 2240/3500, e_loss: 0.0052
# step: 2250/3500, e_loss: 0.0055
# step: 2260/3500, e_loss: 0.0055
# step: 2270/3500, e_loss: 0.0054
# step: 2280/3500, e_loss: 0.0055
# step: 2290/3500, e_loss: 0.0051
# step: 2300/3500, e_loss: 0.0054
# step: 2310/3500, e_loss: 0.0054
# step: 2320/3500, e_loss: 0.0052
# step: 2330/3500, e_loss: 0.005
# step: 2340/3500, e_loss: 0.0053
# step: 2350/3500, e_loss: 0.0051
# step: 2360/3500, e_loss: 0.0051
# step: 2370/3500, e_loss: 0.005
# step: 2380/3500, e_loss: 0.005
# step: 2390/3500, e_loss: 0.0055
# step: 2400/3500, e_loss: 0.0051
# step: 2410/3500, e_loss: 0.0049
# step: 2420/3500, e_loss: 0.0047
# step: 2430/3500, e_loss: 0.0057
# step: 2440/3500, e_loss: 0.0049
# step: 2450/3500, e_loss: 0.0049
# step: 2460/3500, e_loss: 0.0052
# step: 2470/3500, e_loss: 0.0048
# step: 2480/3500, e_loss: 0.0048
# step: 2490/3500, e_loss: 0.0052
# step: 2500/3500, e_loss: 0.0049
# step: 2510/3500, e_loss: 0.0048
# step: 2520/3500, e_loss: 0.0049
# step: 2530/3500, e_loss: 0.0053
# step: 2540/3500, e_loss: 0.0048
# step: 2550/3500, e_loss: 0.0048
# step: 2560/3500, e_loss: 0.0047
# step: 2570/3500, e_loss: 0.0047
# step: 2580/3500, e_loss: 0.0048
# step: 2590/3500, e_loss: 0.0049
# step: 2600/3500, e_loss: 0.0047
# step: 2610/3500, e_loss: 0.0049
# step: 2620/3500, e_loss: 0.0048
# step: 2630/3500, e_loss: 0.0047
# step: 2640/3500, e_loss: 0.0046
# step: 2650/3500, e_loss: 0.0047
# step: 2660/3500, e_loss: 0.0047
# step: 2670/3500, e_loss: 0.0045
# step: 2680/3500, e_loss: 0.0046
# step: 2690/3500, e_loss: 0.0047
# step: 2700/3500, e_loss: 0.0047
# step: 2710/3500, e_loss: 0.0046
# step: 2720/3500, e_loss: 0.0047
# step: 2730/3500, e_loss: 0.0047
# step: 2740/3500, e_loss: 0.0045
# step: 2750/3500, e_loss: 0.0044
# step: 2760/3500, e_loss: 0.0046
# step: 2770/3500, e_loss: 0.0047
# step: 2780/3500, e_loss: 0.0048
# step: 2790/3500, e_loss: 0.0047
# step: 2800/3500, e_loss: 0.0045
# step: 2810/3500, e_loss: 0.0045
# step: 2820/3500, e_loss: 0.0043
# step: 2830/3500, e_loss: 0.0044
# step: 2840/3500, e_loss: 0.0044
# step: 2850/3500, e_loss: 0.0045
# step: 2860/3500, e_loss: 0.0046
# step: 2870/3500, e_loss: 0.0044
# step: 2880/3500, e_loss: 0.0044
# step: 2890/3500, e_loss: 0.0044
# step: 2900/3500, e_loss: 0.0042
# step: 2910/3500, e_loss: 0.0045
# step: 2920/3500, e_loss: 0.0045
# step: 2930/3500, e_loss: 0.0044
# step: 2940/3500, e_loss: 0.0043
# step: 2950/3500, e_loss: 0.0045
# step: 2960/3500, e_loss: 0.0045
# step: 2970/3500, e_loss: 0.0044
# step: 2980/3500, e_loss: 0.0044
# step: 2990/3500, e_loss: 0.0041
# step: 3000/3500, e_loss: 0.0041
# step: 3010/3500, e_loss: 0.0042
# step: 3020/3500, e_loss: 0.0043
# step: 3030/3500, e_loss: 0.0044
# step: 3040/3500, e_loss: 0.0044
# step: 3050/3500, e_loss: 0.0042
# step: 3060/3500, e_loss: 0.0043
# step: 3070/3500, e_loss: 0.0043
# step: 3080/3500, e_loss: 0.0044
# step: 3090/3500, e_loss: 0.0044
# step: 3100/3500, e_loss: 0.0042
# step: 3110/3500, e_loss: 0.0042
# step: 3120/3500, e_loss: 0.0042
# step: 3130/3500, e_loss: 0.0043
# step: 3140/3500, e_loss: 0.0041
# step: 3150/3500, e_loss: 0.0041
# step: 3160/3500, e_loss: 0.0042
# step: 3170/3500, e_loss: 0.0042
# step: 3180/3500, e_loss: 0.0041
# step: 3190/3500, e_loss: 0.004
# step: 3200/3500, e_loss: 0.0042
# step: 3210/3500, e_loss: 0.0041
# step: 3220/3500, e_loss: 0.0039
# step: 3230/3500, e_loss: 0.0039
# step: 3240/3500, e_loss: 0.004
# step: 3250/3500, e_loss: 0.004
# step: 3260/3500, e_loss: 0.0039
# step: 3270/3500, e_loss: 0.0043
# step: 3280/3500, e_loss: 0.0043
# step: 3290/3500, e_loss: 0.0043
# step: 3300/3500, e_loss: 0.0042
# step: 3310/3500, e_loss: 0.0041
# step: 3320/3500, e_loss: 0.0039
# step: 3330/3500, e_loss: 0.0041
# step: 3340/3500, e_loss: 0.0043
# step: 3350/3500, e_loss: 0.0044
# step: 3360/3500, e_loss: 0.0041
# step: 3370/3500, e_loss: 0.0039
# step: 3380/3500, e_loss: 0.0039
# step: 3390/3500, e_loss: 0.0039
# step: 3400/3500, e_loss: 0.004
# step: 3410/3500, e_loss: 0.0041
# step: 3420/3500, e_loss: 0.0041
# step: 3430/3500, e_loss: 0.004
# step: 3440/3500, e_loss: 0.0041
# step: 3450/3500, e_loss: 0.0041
# step: 3460/3500, e_loss: 0.0043
# step: 3470/3500, e_loss: 0.004
# step: 3480/3500, e_loss: 0.0039
# step: 3490/3500, e_loss: 0.0039
# Finish Embedding Network Training
# Start Training with Supervised Loss Only
# step: 0/8000, s_loss: 0.1618
# step: 10/8000, s_loss: 0.1378
# step: 20/8000, s_loss: 0.1178
# step: 30/8000, s_loss: 0.1022
# step: 40/8000, s_loss: 0.0911
# step: 50/8000, s_loss: 0.0843
# step: 60/8000, s_loss: 0.079
# step: 70/8000, s_loss: 0.0747
# step: 80/8000, s_loss: 0.0716
# step: 90/8000, s_loss: 0.0682
# step: 100/8000, s_loss: 0.0642
# step: 110/8000, s_loss: 0.0608
# step: 120/8000, s_loss: 0.0572
# step: 130/8000, s_loss: 0.053
# step: 140/8000, s_loss: 0.0497
# step: 150/8000, s_loss: 0.0465
# step: 160/8000, s_loss: 0.044
# step: 170/8000, s_loss: 0.0412
# step: 180/8000, s_loss: 0.0388
# step: 190/8000, s_loss: 0.0369
# step: 200/8000, s_loss: 0.035
# step: 210/8000, s_loss: 0.033
# step: 220/8000, s_loss: 0.0311
# step: 230/8000, s_loss: 0.0289
# step: 240/8000, s_loss: 0.0274
# step: 250/8000, s_loss: 0.0255
# step: 260/8000, s_loss: 0.0242
# step: 270/8000, s_loss: 0.0226
# step: 280/8000, s_loss: 0.0213
# step: 290/8000, s_loss: 0.0199
# step: 300/8000, s_loss: 0.0188
# step: 310/8000, s_loss: 0.018
# step: 320/8000, s_loss: 0.0168
# step: 330/8000, s_loss: 0.016
# step: 340/8000, s_loss: 0.0153
# step: 350/8000, s_loss: 0.0148
# step: 360/8000, s_loss: 0.0141
# step: 370/8000, s_loss: 0.0138
# step: 380/8000, s_loss: 0.0133
# step: 390/8000, s_loss: 0.0129
# step: 400/8000, s_loss: 0.0127
# step: 410/8000, s_loss: 0.0125
# step: 420/8000, s_loss: 0.0121
# step: 430/8000, s_loss: 0.0119
# step: 440/8000, s_loss: 0.0118
# step: 450/8000, s_loss: 0.0116
# step: 460/8000, s_loss: 0.0113
# step: 470/8000, s_loss: 0.011
# step: 480/8000, s_loss: 0.0111
# step: 490/8000, s_loss: 0.0111
# step: 500/8000, s_loss: 0.0109
# step: 510/8000, s_loss: 0.0108
# step: 520/8000, s_loss: 0.0106
# step: 530/8000, s_loss: 0.0105
# step: 540/8000, s_loss: 0.0103
# step: 550/8000, s_loss: 0.0104
# step: 560/8000, s_loss: 0.0103
# step: 570/8000, s_loss: 0.0102
# step: 580/8000, s_loss: 0.01
# step: 590/8000, s_loss: 0.0098
# step: 600/8000, s_loss: 0.0098
# step: 610/8000, s_loss: 0.0098
# step: 620/8000, s_loss: 0.0098
# step: 630/8000, s_loss: 0.0098
# step: 640/8000, s_loss: 0.0096
# step: 650/8000, s_loss: 0.0095
# step: 660/8000, s_loss: 0.0095
# step: 670/8000, s_loss: 0.0094
# step: 680/8000, s_loss: 0.0093
# step: 690/8000, s_loss: 0.0094
# step: 700/8000, s_loss: 0.0092
# step: 710/8000, s_loss: 0.009
# step: 720/8000, s_loss: 0.0091
# step: 730/8000, s_loss: 0.0091
# step: 740/8000, s_loss: 0.009
# step: 750/8000, s_loss: 0.0088
# step: 760/8000, s_loss: 0.0089
# step: 770/8000, s_loss: 0.0088
# step: 780/8000, s_loss: 0.0088
# step: 790/8000, s_loss: 0.0088
# step: 800/8000, s_loss: 0.0087
# step: 810/8000, s_loss: 0.0085
# step: 820/8000, s_loss: 0.0085
# step: 830/8000, s_loss: 0.0086
# step: 840/8000, s_loss: 0.0085
# step: 850/8000, s_loss: 0.0084
# step: 860/8000, s_loss: 0.0083
# step: 870/8000, s_loss: 0.0084
# step: 880/8000, s_loss: 0.0083
# step: 890/8000, s_loss: 0.0083
# step: 900/8000, s_loss: 0.0081
# step: 910/8000, s_loss: 0.0081
# step: 920/8000, s_loss: 0.0081
# step: 930/8000, s_loss: 0.008
# step: 940/8000, s_loss: 0.008
# step: 950/8000, s_loss: 0.008
# step: 960/8000, s_loss: 0.0079
# step: 970/8000, s_loss: 0.008
# step: 980/8000, s_loss: 0.0079
# step: 990/8000, s_loss: 0.0079
# step: 1000/8000, s_loss: 0.0079
# step: 1010/8000, s_loss: 0.0077
# step: 1020/8000, s_loss: 0.0078
# step: 1030/8000, s_loss: 0.0077
# step: 1040/8000, s_loss: 0.0076
# step: 1050/8000, s_loss: 0.0077
# step: 1060/8000, s_loss: 0.0076
# step: 1070/8000, s_loss: 0.0075
# step: 1080/8000, s_loss: 0.0075
# step: 1090/8000, s_loss: 0.0075
# step: 1100/8000, s_loss: 0.0074
# step: 1110/8000, s_loss: 0.0073
# step: 1120/8000, s_loss: 0.0074
# step: 1130/8000, s_loss: 0.0073
# step: 1140/8000, s_loss: 0.0072
# step: 1150/8000, s_loss: 0.0072
# step: 1160/8000, s_loss: 0.0073
# step: 1170/8000, s_loss: 0.0072
# step: 1180/8000, s_loss: 0.0072
# step: 1190/8000, s_loss: 0.0071
# step: 1200/8000, s_loss: 0.0071
# step: 1210/8000, s_loss: 0.0071
# step: 1220/8000, s_loss: 0.007
# step: 1230/8000, s_loss: 0.007
# step: 1240/8000, s_loss: 0.007
# step: 1250/8000, s_loss: 0.007
# step: 1260/8000, s_loss: 0.0069
# step: 1270/8000, s_loss: 0.0069
# step: 1280/8000, s_loss: 0.0069
# step: 1290/8000, s_loss: 0.0068
# step: 1300/8000, s_loss: 0.0068
# step: 1310/8000, s_loss: 0.0067
# step: 1320/8000, s_loss: 0.0067
# step: 1330/8000, s_loss: 0.0067
# step: 1340/8000, s_loss: 0.0066
# step: 1350/8000, s_loss: 0.0066
# step: 1360/8000, s_loss: 0.0066
# step: 1370/8000, s_loss: 0.0066
# step: 1380/8000, s_loss: 0.0065
# step: 1390/8000, s_loss: 0.0065
# step: 1400/8000, s_loss: 0.0065
# step: 1410/8000, s_loss: 0.0064
# step: 1420/8000, s_loss: 0.0064
# step: 1430/8000, s_loss: 0.0064
# step: 1440/8000, s_loss: 0.0063
# step: 1450/8000, s_loss: 0.0063
# step: 1460/8000, s_loss: 0.0063
# step: 1470/8000, s_loss: 0.0063
# step: 1480/8000, s_loss: 0.0063
# step: 1490/8000, s_loss: 0.0062
# step: 1500/8000, s_loss: 0.0062
# step: 1510/8000, s_loss: 0.0062
# step: 1520/8000, s_loss: 0.0062
# step: 1530/8000, s_loss: 0.0061
# step: 1540/8000, s_loss: 0.0061
# step: 1550/8000, s_loss: 0.0061
# step: 1560/8000, s_loss: 0.0061
# step: 1570/8000, s_loss: 0.006
# step: 1580/8000, s_loss: 0.006
# step: 1590/8000, s_loss: 0.006
# step: 1600/8000, s_loss: 0.0059
# step: 1610/8000, s_loss: 0.0059
# step: 1620/8000, s_loss: 0.0058
# step: 1630/8000, s_loss: 0.0058
# step: 1640/8000, s_loss: 0.0058
# step: 1650/8000, s_loss: 0.0058
# step: 1660/8000, s_loss: 0.0058
# step: 1670/8000, s_loss: 0.0057
# step: 1680/8000, s_loss: 0.0057
# step: 1690/8000, s_loss: 0.0057
# step: 1700/8000, s_loss: 0.0057
# step: 1710/8000, s_loss: 0.0057
# step: 1720/8000, s_loss: 0.0056
# step: 1730/8000, s_loss: 0.0055
# step: 1740/8000, s_loss: 0.0055
# step: 1750/8000, s_loss: 0.0055
# step: 1760/8000, s_loss: 0.0056
# step: 1770/8000, s_loss: 0.0055
# step: 1780/8000, s_loss: 0.0054
# step: 1790/8000, s_loss: 0.0055
# step: 1800/8000, s_loss: 0.0054
# step: 1810/8000, s_loss: 0.0054
# step: 1820/8000, s_loss: 0.0054
# step: 1830/8000, s_loss: 0.0053
# step: 1840/8000, s_loss: 0.0053
# step: 1850/8000, s_loss: 0.0053
# step: 1860/8000, s_loss: 0.0053
# step: 1870/8000, s_loss: 0.0052
# step: 1880/8000, s_loss: 0.0052
# step: 1890/8000, s_loss: 0.0052
# step: 1900/8000, s_loss: 0.0052
# step: 1910/8000, s_loss: 0.0051
# step: 1920/8000, s_loss: 0.0051
# step: 1930/8000, s_loss: 0.0051
# step: 1940/8000, s_loss: 0.0051
# step: 1950/8000, s_loss: 0.005
# step: 1960/8000, s_loss: 0.005
# step: 1970/8000, s_loss: 0.005
# step: 1980/8000, s_loss: 0.005
# step: 1990/8000, s_loss: 0.005
# step: 2000/8000, s_loss: 0.005
# step: 2010/8000, s_loss: 0.0049
# step: 2020/8000, s_loss: 0.0048
# step: 2030/8000, s_loss: 0.0049
# step: 2040/8000, s_loss: 0.0049
# step: 2050/8000, s_loss: 0.0049
# step: 2060/8000, s_loss: 0.0048
# step: 2070/8000, s_loss: 0.0048
# step: 2080/8000, s_loss: 0.0048
# step: 2090/8000, s_loss: 0.0047
# step: 2100/8000, s_loss: 0.0047
# step: 2110/8000, s_loss: 0.0047
# step: 2120/8000, s_loss: 0.0047
# step: 2130/8000, s_loss: 0.0046
# step: 2140/8000, s_loss: 0.0047
# step: 2150/8000, s_loss: 0.0046
# step: 2160/8000, s_loss: 0.0046
# step: 2170/8000, s_loss: 0.0046
# step: 2180/8000, s_loss: 0.0045
# step: 2190/8000, s_loss: 0.0045
# step: 2200/8000, s_loss: 0.0045
# step: 2210/8000, s_loss: 0.0045
# step: 2220/8000, s_loss: 0.0045
# step: 2230/8000, s_loss: 0.0045
# step: 2240/8000, s_loss: 0.0045
# step: 2250/8000, s_loss: 0.0044
# step: 2260/8000, s_loss: 0.0044
# step: 2270/8000, s_loss: 0.0044
# step: 2280/8000, s_loss: 0.0044
# step: 2290/8000, s_loss: 0.0043
# step: 2300/8000, s_loss: 0.0044
# step: 2310/8000, s_loss: 0.0043
# step: 2320/8000, s_loss: 0.0043
# step: 2330/8000, s_loss: 0.0043
# step: 2340/8000, s_loss: 0.0043
# step: 2350/8000, s_loss: 0.0043
# step: 2360/8000, s_loss: 0.0042
# step: 2370/8000, s_loss: 0.0042
# step: 2380/8000, s_loss: 0.0042
# step: 2390/8000, s_loss: 0.0042
# step: 2400/8000, s_loss: 0.0042
# step: 2410/8000, s_loss: 0.0041
# step: 2420/8000, s_loss: 0.0041
# step: 2430/8000, s_loss: 0.0041
# step: 2440/8000, s_loss: 0.0041
# step: 2450/8000, s_loss: 0.0041
# step: 2460/8000, s_loss: 0.0041
# step: 2470/8000, s_loss: 0.004
# step: 2480/8000, s_loss: 0.0041
# step: 2490/8000, s_loss: 0.004
# step: 2500/8000, s_loss: 0.004
# step: 2510/8000, s_loss: 0.004
# step: 2520/8000, s_loss: 0.004
# step: 2530/8000, s_loss: 0.0039
# step: 2540/8000, s_loss: 0.0039
# step: 2550/8000, s_loss: 0.0039
# step: 2560/8000, s_loss: 0.0039
# step: 2570/8000, s_loss: 0.0039
# step: 2580/8000, s_loss: 0.0039
# step: 2590/8000, s_loss: 0.0039
# step: 2600/8000, s_loss: 0.0039
# step: 2610/8000, s_loss: 0.0039
# step: 2620/8000, s_loss: 0.0038
# step: 2630/8000, s_loss: 0.0038
# step: 2640/8000, s_loss: 0.0038
# step: 2650/8000, s_loss: 0.0038
# step: 2660/8000, s_loss: 0.0038
# step: 2670/8000, s_loss: 0.0038
# step: 2680/8000, s_loss: 0.0038
# step: 2690/8000, s_loss: 0.0038
# step: 2700/8000, s_loss: 0.0037
# step: 2710/8000, s_loss: 0.0037
# step: 2720/8000, s_loss: 0.0037
# step: 2730/8000, s_loss: 0.0037
# step: 2740/8000, s_loss: 0.0037
# step: 2750/8000, s_loss: 0.0037
# step: 2760/8000, s_loss: 0.0037
# step: 2770/8000, s_loss: 0.0037
# step: 2780/8000, s_loss: 0.0037
# step: 2790/8000, s_loss: 0.0037
# step: 2800/8000, s_loss: 0.0036
# step: 2810/8000, s_loss: 0.0036
# step: 2820/8000, s_loss: 0.0036
# step: 2830/8000, s_loss: 0.0036
# step: 2840/8000, s_loss: 0.0036
# step: 2850/8000, s_loss: 0.0036
# step: 2860/8000, s_loss: 0.0036
# step: 2870/8000, s_loss: 0.0036
# step: 2880/8000, s_loss: 0.0036
# step: 2890/8000, s_loss: 0.0036
# step: 2900/8000, s_loss: 0.0035
# step: 2910/8000, s_loss: 0.0036
# step: 2920/8000, s_loss: 0.0035
# step: 2930/8000, s_loss: 0.0035
# step: 2940/8000, s_loss: 0.0035
# step: 2950/8000, s_loss: 0.0035
# step: 2960/8000, s_loss: 0.0035
# step: 2970/8000, s_loss: 0.0035
# step: 2980/8000, s_loss: 0.0034
# step: 2990/8000, s_loss: 0.0034
# step: 3000/8000, s_loss: 0.0034
# step: 3010/8000, s_loss: 0.0034
# step: 3020/8000, s_loss: 0.0035
# step: 3030/8000, s_loss: 0.0035
# step: 3040/8000, s_loss: 0.0035
# step: 3050/8000, s_loss: 0.0034
# step: 3060/8000, s_loss: 0.0034
# step: 3070/8000, s_loss: 0.0034
# step: 3080/8000, s_loss: 0.0034
# step: 3090/8000, s_loss: 0.0034
# step: 3100/8000, s_loss: 0.0034
# step: 3110/8000, s_loss: 0.0035
# step: 3120/8000, s_loss: 0.0034
# step: 3130/8000, s_loss: 0.0034
# step: 3140/8000, s_loss: 0.0034
# step: 3150/8000, s_loss: 0.0034
# step: 3160/8000, s_loss: 0.0034
# step: 3170/8000, s_loss: 0.0034
# step: 3180/8000, s_loss: 0.0034
# step: 3190/8000, s_loss: 0.0033
# step: 3200/8000, s_loss: 0.0033
# step: 3210/8000, s_loss: 0.0033
# step: 3220/8000, s_loss: 0.0033
# step: 3230/8000, s_loss: 0.0033
# step: 3240/8000, s_loss: 0.0033
# step: 3250/8000, s_loss: 0.0033
# step: 3260/8000, s_loss: 0.0033
# step: 3270/8000, s_loss: 0.0033
# step: 3280/8000, s_loss: 0.0033
# step: 3290/8000, s_loss: 0.0033
# step: 3300/8000, s_loss: 0.0032
# step: 3310/8000, s_loss: 0.0032
# step: 3320/8000, s_loss: 0.0032
# step: 3330/8000, s_loss: 0.0032
# step: 3340/8000, s_loss: 0.0032
# step: 3350/8000, s_loss: 0.0032
# step: 3360/8000, s_loss: 0.0032
# step: 3370/8000, s_loss: 0.0032
# step: 3380/8000, s_loss: 0.0032
# step: 3390/8000, s_loss: 0.0032
# step: 3400/8000, s_loss: 0.0032
# step: 3410/8000, s_loss: 0.0032
# step: 3420/8000, s_loss: 0.0032
# step: 3430/8000, s_loss: 0.0032
# step: 3440/8000, s_loss: 0.0032
# step: 3450/8000, s_loss: 0.0031
# step: 3460/8000, s_loss: 0.0031
# step: 3470/8000, s_loss: 0.0032
# step: 3480/8000, s_loss: 0.0032
# step: 3490/8000, s_loss: 0.0032
# step: 3500/8000, s_loss: 0.0031
# step: 3510/8000, s_loss: 0.0031
# step: 3520/8000, s_loss: 0.0031
# step: 3530/8000, s_loss: 0.0031
# step: 3540/8000, s_loss: 0.0031
# step: 3550/8000, s_loss: 0.0031
# step: 3560/8000, s_loss: 0.0031
# step: 3570/8000, s_loss: 0.0031
# step: 3580/8000, s_loss: 0.003
# step: 3590/8000, s_loss: 0.0031
# step: 3600/8000, s_loss: 0.003
# step: 3610/8000, s_loss: 0.003
# step: 3620/8000, s_loss: 0.0031
# step: 3630/8000, s_loss: 0.003
# step: 3640/8000, s_loss: 0.003
# step: 3650/8000, s_loss: 0.003
# step: 3660/8000, s_loss: 0.003
# step: 3670/8000, s_loss: 0.003
# step: 3680/8000, s_loss: 0.003
# step: 3690/8000, s_loss: 0.003
# step: 3700/8000, s_loss: 0.003
# step: 3710/8000, s_loss: 0.003
# step: 3720/8000, s_loss: 0.003
# step: 3730/8000, s_loss: 0.003
# step: 3740/8000, s_loss: 0.003
# step: 3750/8000, s_loss: 0.003
# step: 3760/8000, s_loss: 0.003
# step: 3770/8000, s_loss: 0.003
# step: 3780/8000, s_loss: 0.0029
# step: 3790/8000, s_loss: 0.003
# step: 3800/8000, s_loss: 0.003
# step: 3810/8000, s_loss: 0.0029
# step: 3820/8000, s_loss: 0.0029
# step: 3830/8000, s_loss: 0.0029
# step: 3840/8000, s_loss: 0.0029
# step: 3850/8000, s_loss: 0.0029
# step: 3860/8000, s_loss: 0.0029
# step: 3870/8000, s_loss: 0.0029
# step: 3880/8000, s_loss: 0.0029
# step: 3890/8000, s_loss: 0.0029
# step: 3900/8000, s_loss: 0.0029
# step: 3910/8000, s_loss: 0.0029
# step: 3920/8000, s_loss: 0.0029
# step: 3930/8000, s_loss: 0.0029
# step: 3940/8000, s_loss: 0.0029
# step: 3950/8000, s_loss: 0.0029
# step: 3960/8000, s_loss: 0.0029
# step: 3970/8000, s_loss: 0.0029
# step: 3980/8000, s_loss: 0.0029
# step: 3990/8000, s_loss: 0.0029
# step: 4000/8000, s_loss: 0.0028
# step: 4010/8000, s_loss: 0.0029
# step: 4020/8000, s_loss: 0.0028
# step: 4030/8000, s_loss: 0.0028
# step: 4040/8000, s_loss: 0.0028
# step: 4050/8000, s_loss: 0.0028
# step: 4060/8000, s_loss: 0.0028
# step: 4070/8000, s_loss: 0.0028
# step: 4080/8000, s_loss: 0.0028
# step: 4090/8000, s_loss: 0.0028
# step: 4100/8000, s_loss: 0.0028
# step: 4110/8000, s_loss: 0.0028
# step: 4120/8000, s_loss: 0.0028
# step: 4130/8000, s_loss: 0.0028
# step: 4140/8000, s_loss: 0.0028
# step: 4150/8000, s_loss: 0.0028
# step: 4160/8000, s_loss: 0.0028
# step: 4170/8000, s_loss: 0.0028
# step: 4180/8000, s_loss: 0.0028
# step: 4190/8000, s_loss: 0.0027
# step: 4200/8000, s_loss: 0.0027
# step: 4210/8000, s_loss: 0.0028
# step: 4220/8000, s_loss: 0.0027
# step: 4230/8000, s_loss: 0.0027
# step: 4240/8000, s_loss: 0.0027
# step: 4250/8000, s_loss: 0.0027
# step: 4260/8000, s_loss: 0.0027
# step: 4270/8000, s_loss: 0.0027
# step: 4280/8000, s_loss: 0.0027
# step: 4290/8000, s_loss: 0.0027
# step: 4300/8000, s_loss: 0.0027
# step: 4310/8000, s_loss: 0.0027
# step: 4320/8000, s_loss: 0.0027
# step: 4330/8000, s_loss: 0.0027
# step: 4340/8000, s_loss: 0.0027
# step: 4350/8000, s_loss: 0.0026
# step: 4360/8000, s_loss: 0.0026
# step: 4370/8000, s_loss: 0.0027
# step: 4380/8000, s_loss: 0.0027
# step: 4390/8000, s_loss: 0.0026
# step: 4400/8000, s_loss: 0.0027
# step: 4410/8000, s_loss: 0.0026
# step: 4420/8000, s_loss: 0.0026
# step: 4430/8000, s_loss: 0.0026
# step: 4440/8000, s_loss: 0.0026
# step: 4450/8000, s_loss: 0.0026
# step: 4460/8000, s_loss: 0.0026
# step: 4470/8000, s_loss: 0.0026
# step: 4480/8000, s_loss: 0.0027
# step: 4490/8000, s_loss: 0.0026
# step: 4500/8000, s_loss: 0.0026
# step: 4510/8000, s_loss: 0.0026
# step: 4520/8000, s_loss: 0.0026
# step: 4530/8000, s_loss: 0.0025
# step: 4540/8000, s_loss: 0.0026
# step: 4550/8000, s_loss: 0.0026
# step: 4560/8000, s_loss: 0.0026
# step: 4570/8000, s_loss: 0.0026
# step: 4580/8000, s_loss: 0.0025
# step: 4590/8000, s_loss: 0.0025
# step: 4600/8000, s_loss: 0.0025
# step: 4610/8000, s_loss: 0.0026
# step: 4620/8000, s_loss: 0.0026
# step: 4630/8000, s_loss: 0.0025
# step: 4640/8000, s_loss: 0.0025
# step: 4650/8000, s_loss: 0.0025
# step: 4660/8000, s_loss: 0.0025
# step: 4670/8000, s_loss: 0.0025
# step: 4680/8000, s_loss: 0.0025
# step: 4690/8000, s_loss: 0.0025
# step: 4700/8000, s_loss: 0.0025
# step: 4710/8000, s_loss: 0.0025
# step: 4720/8000, s_loss: 0.0025
# step: 4730/8000, s_loss: 0.0025
# step: 4740/8000, s_loss: 0.0025
# step: 4750/8000, s_loss: 0.0024
# step: 4760/8000, s_loss: 0.0025
# step: 4770/8000, s_loss: 0.0025
# step: 4780/8000, s_loss: 0.0025
# step: 4790/8000, s_loss: 0.0025
# step: 4800/8000, s_loss: 0.0025
# step: 4810/8000, s_loss: 0.0024
# step: 4820/8000, s_loss: 0.0024
# step: 4830/8000, s_loss: 0.0024
# step: 4840/8000, s_loss: 0.0024
# step: 4850/8000, s_loss: 0.0024
# step: 4860/8000, s_loss: 0.0024
# step: 4870/8000, s_loss: 0.0024
# step: 4880/8000, s_loss: 0.0025
# step: 4890/8000, s_loss: 0.0024
# step: 4900/8000, s_loss: 0.0024
# step: 4910/8000, s_loss: 0.0024
# step: 4920/8000, s_loss: 0.0025
# step: 4930/8000, s_loss: 0.0024
# step: 4940/8000, s_loss: 0.0024
# step: 4950/8000, s_loss: 0.0024
# step: 4960/8000, s_loss: 0.0024
# step: 4970/8000, s_loss: 0.0024
# step: 4980/8000, s_loss: 0.0024
# step: 4990/8000, s_loss: 0.0024
# step: 5000/8000, s_loss: 0.0024
# step: 5010/8000, s_loss: 0.0023
# step: 5020/8000, s_loss: 0.0023
# step: 5030/8000, s_loss: 0.0024
# step: 5040/8000, s_loss: 0.0024
# step: 5050/8000, s_loss: 0.0023
# step: 5060/8000, s_loss: 0.0023
# step: 5070/8000, s_loss: 0.0023
# step: 5080/8000, s_loss: 0.0023
# step: 5090/8000, s_loss: 0.0023
# step: 5100/8000, s_loss: 0.0023
# step: 5110/8000, s_loss: 0.0023
# step: 5120/8000, s_loss: 0.0024
# step: 5130/8000, s_loss: 0.0023
# step: 5140/8000, s_loss: 0.0023
# step: 5150/8000, s_loss: 0.0023
# step: 5160/8000, s_loss: 0.0023
# step: 5170/8000, s_loss: 0.0023
# step: 5180/8000, s_loss: 0.0023
# step: 5190/8000, s_loss: 0.0023
# step: 5200/8000, s_loss: 0.0023
# step: 5210/8000, s_loss: 0.0023
# step: 5220/8000, s_loss: 0.0025
# step: 5230/8000, s_loss: 0.0023
# step: 5240/8000, s_loss: 0.0023
# step: 5250/8000, s_loss: 0.0022
# step: 5260/8000, s_loss: 0.0022
# step: 5270/8000, s_loss: 0.0022
# step: 5280/8000, s_loss: 0.0022
# step: 5290/8000, s_loss: 0.0022
# step: 5300/8000, s_loss: 0.0022
# step: 5310/8000, s_loss: 0.0022
# step: 5320/8000, s_loss: 0.0022
# step: 5330/8000, s_loss: 0.0022
# step: 5340/8000, s_loss: 0.0022
# step: 5350/8000, s_loss: 0.0022
# step: 5360/8000, s_loss: 0.0022
# step: 5370/8000, s_loss: 0.0022
# step: 5380/8000, s_loss: 0.0022
# step: 5390/8000, s_loss: 0.0022
# step: 5400/8000, s_loss: 0.0022
# step: 5410/8000, s_loss: 0.0022
# step: 5420/8000, s_loss: 0.0023
# step: 5430/8000, s_loss: 0.0022
# step: 5440/8000, s_loss: 0.0022
# step: 5450/8000, s_loss: 0.0022
# step: 5460/8000, s_loss: 0.0022
# step: 5470/8000, s_loss: 0.0021
# step: 5480/8000, s_loss: 0.0022
# step: 5490/8000, s_loss: 0.0021
# step: 5500/8000, s_loss: 0.0021
# step: 5510/8000, s_loss: 0.0022
# step: 5520/8000, s_loss: 0.0022
# step: 5530/8000, s_loss: 0.0021
# step: 5540/8000, s_loss: 0.0021
# step: 5550/8000, s_loss: 0.0021
# step: 5560/8000, s_loss: 0.0023
# step: 5570/8000, s_loss: 0.0021
# step: 5580/8000, s_loss: 0.0021
# step: 5590/8000, s_loss: 0.0021
# step: 5600/8000, s_loss: 0.0021
# step: 5610/8000, s_loss: 0.0021
# step: 5620/8000, s_loss: 0.0021
# step: 5630/8000, s_loss: 0.0021
# step: 5640/8000, s_loss: 0.0021
# step: 5650/8000, s_loss: 0.0021
# step: 5660/8000, s_loss: 0.0021
# step: 5670/8000, s_loss: 0.0021
# step: 5680/8000, s_loss: 0.0022
# step: 5690/8000, s_loss: 0.0021
# step: 5700/8000, s_loss: 0.0021
# step: 5710/8000, s_loss: 0.0021
# step: 5720/8000, s_loss: 0.0021
# step: 5730/8000, s_loss: 0.0021
# step: 5740/8000, s_loss: 0.0021
# step: 5750/8000, s_loss: 0.002
# step: 5760/8000, s_loss: 0.002
# step: 5770/8000, s_loss: 0.0021
# step: 5780/8000, s_loss: 0.002
# step: 5790/8000, s_loss: 0.002
# step: 5800/8000, s_loss: 0.002
# step: 5810/8000, s_loss: 0.002
# step: 5820/8000, s_loss: 0.002
# step: 5830/8000, s_loss: 0.002
# step: 5840/8000, s_loss: 0.0022
# step: 5850/8000, s_loss: 0.002
# step: 5860/8000, s_loss: 0.002
# step: 5870/8000, s_loss: 0.002
# step: 5880/8000, s_loss: 0.002
# step: 5890/8000, s_loss: 0.002
# step: 5900/8000, s_loss: 0.002
# step: 5910/8000, s_loss: 0.002
# step: 5920/8000, s_loss: 0.002
# step: 5930/8000, s_loss: 0.002
# step: 5940/8000, s_loss: 0.002
# step: 5950/8000, s_loss: 0.002
# step: 5960/8000, s_loss: 0.0023
# step: 5970/8000, s_loss: 0.002
# step: 5980/8000, s_loss: 0.002
# step: 5990/8000, s_loss: 0.002
# step: 6000/8000, s_loss: 0.002
# step: 6010/8000, s_loss: 0.0019
# step: 6020/8000, s_loss: 0.002
# step: 6030/8000, s_loss: 0.0019
# step: 6040/8000, s_loss: 0.0019
# step: 6050/8000, s_loss: 0.0019
# step: 6060/8000, s_loss: 0.0019
# step: 6070/8000, s_loss: 0.0019
# step: 6080/8000, s_loss: 0.002
# step: 6090/8000, s_loss: 0.0021
# step: 6100/8000, s_loss: 0.0019
# step: 6110/8000, s_loss: 0.0019
# step: 6120/8000, s_loss: 0.0019
# step: 6130/8000, s_loss: 0.0019
# step: 6140/8000, s_loss: 0.0019
# step: 6150/8000, s_loss: 0.0019
# step: 6160/8000, s_loss: 0.0019
# step: 6170/8000, s_loss: 0.0019
# step: 6180/8000, s_loss: 0.0019
# step: 6190/8000, s_loss: 0.0022
# step: 6200/8000, s_loss: 0.0019
# step: 6210/8000, s_loss: 0.0019
# step: 6220/8000, s_loss: 0.0019
# step: 6230/8000, s_loss: 0.0019
# step: 6240/8000, s_loss: 0.0019
# step: 6250/8000, s_loss: 0.0019
# step: 6260/8000, s_loss: 0.0019
# step: 6270/8000, s_loss: 0.0019
# step: 6280/8000, s_loss: 0.0019
# step: 6290/8000, s_loss: 0.0019
# step: 6300/8000, s_loss: 0.0019
# step: 6310/8000, s_loss: 0.0019
# step: 6320/8000, s_loss: 0.0019
# step: 6330/8000, s_loss: 0.0019
# step: 6340/8000, s_loss: 0.002
# step: 6350/8000, s_loss: 0.0019
# step: 6360/8000, s_loss: 0.002
# step: 6370/8000, s_loss: 0.0019
# step: 6380/8000, s_loss: 0.0018
# step: 6390/8000, s_loss: 0.0018
# step: 6400/8000, s_loss: 0.0018
# step: 6410/8000, s_loss: 0.0018
# step: 6420/8000, s_loss: 0.0018
# step: 6430/8000, s_loss: 0.0018
# step: 6440/8000, s_loss: 0.002
# step: 6450/8000, s_loss: 0.0019
# step: 6460/8000, s_loss: 0.0018
# step: 6470/8000, s_loss: 0.0018
# step: 6480/8000, s_loss: 0.0018
# step: 6490/8000, s_loss: 0.0018
# step: 6500/8000, s_loss: 0.0018
# step: 6510/8000, s_loss: 0.0018
# step: 6520/8000, s_loss: 0.0018
# step: 6530/8000, s_loss: 0.0018
# step: 6540/8000, s_loss: 0.0018
# step: 6550/8000, s_loss: 0.0019
# step: 6560/8000, s_loss: 0.0019
# step: 6570/8000, s_loss: 0.0019
# step: 6580/8000, s_loss: 0.0018
# step: 6590/8000, s_loss: 0.0018
# step: 6600/8000, s_loss: 0.0018
# step: 6610/8000, s_loss: 0.0018
# step: 6620/8000, s_loss: 0.0018
# step: 6630/8000, s_loss: 0.0018
# step: 6640/8000, s_loss: 0.0018
# step: 6650/8000, s_loss: 0.0018
# step: 6660/8000, s_loss: 0.0018
# step: 6670/8000, s_loss: 0.0018
# step: 6680/8000, s_loss: 0.0018
# step: 6690/8000, s_loss: 0.0021
# step: 6700/8000, s_loss: 0.0018
# step: 6710/8000, s_loss: 0.0017
# step: 6720/8000, s_loss: 0.0017
# step: 6730/8000, s_loss: 0.0017
# step: 6740/8000, s_loss: 0.0017
# step: 6750/8000, s_loss: 0.0017
# step: 6760/8000, s_loss: 0.0017
# step: 6770/8000, s_loss: 0.0017
# step: 6780/8000, s_loss: 0.0017
# step: 6790/8000, s_loss: 0.0018
# step: 6800/8000, s_loss: 0.0017
# step: 6810/8000, s_loss: 0.0017
# step: 6820/8000, s_loss: 0.0017
# step: 6830/8000, s_loss: 0.0017
# step: 6840/8000, s_loss: 0.0018
# step: 6850/8000, s_loss: 0.0018
# step: 6860/8000, s_loss: 0.0018
# step: 6870/8000, s_loss: 0.0017
# step: 6880/8000, s_loss: 0.0017
# step: 6890/8000, s_loss: 0.0017
# step: 6900/8000, s_loss: 0.0017
# step: 6910/8000, s_loss: 0.0018
# step: 6920/8000, s_loss: 0.0017
# step: 6930/8000, s_loss: 0.0017
# step: 6940/8000, s_loss: 0.0017
# step: 6950/8000, s_loss: 0.0017
# step: 6960/8000, s_loss: 0.0018
# step: 6970/8000, s_loss: 0.0018
# step: 6980/8000, s_loss: 0.0017
# step: 6990/8000, s_loss: 0.0017
# step: 7000/8000, s_loss: 0.0017
# step: 7010/8000, s_loss: 0.0017
# step: 7020/8000, s_loss: 0.0017
# step: 7030/8000, s_loss: 0.0017
# step: 7040/8000, s_loss: 0.0017
# step: 7050/8000, s_loss: 0.0017
# step: 7060/8000, s_loss: 0.0017
# step: 7070/8000, s_loss: 0.0017
# step: 7080/8000, s_loss: 0.0017
# step: 7090/8000, s_loss: 0.0018
# step: 7100/8000, s_loss: 0.0017
# step: 7110/8000, s_loss: 0.0017
# step: 7120/8000, s_loss: 0.0017
# step: 7130/8000, s_loss: 0.0016
# step: 7140/8000, s_loss: 0.0016
# step: 7150/8000, s_loss: 0.0017
# step: 7160/8000, s_loss: 0.0017
# step: 7170/8000, s_loss: 0.0018
# step: 7180/8000, s_loss: 0.0017
# step: 7190/8000, s_loss: 0.0016
# step: 7200/8000, s_loss: 0.0016
# step: 7210/8000, s_loss: 0.0016
# step: 7220/8000, s_loss: 0.0016
# step: 7230/8000, s_loss: 0.0016
# step: 7240/8000, s_loss: 0.0016
# step: 7250/8000, s_loss: 0.0017
# step: 7260/8000, s_loss: 0.0018
# step: 7270/8000, s_loss: 0.0017
# step: 7280/8000, s_loss: 0.0016
# step: 7290/8000, s_loss: 0.0016
# step: 7300/8000, s_loss: 0.0016
# step: 7310/8000, s_loss: 0.0017
# step: 7320/8000, s_loss: 0.0016
# step: 7330/8000, s_loss: 0.0017
# step: 7340/8000, s_loss: 0.0016
# step: 7350/8000, s_loss: 0.0016
# step: 7360/8000, s_loss: 0.0017
# step: 7370/8000, s_loss: 0.0016
# step: 7380/8000, s_loss: 0.0016
# step: 7390/8000, s_loss: 0.0016
# step: 7400/8000, s_loss: 0.0017
# step: 7410/8000, s_loss: 0.0016
# step: 7420/8000, s_loss: 0.0016
# step: 7430/8000, s_loss: 0.0016
# step: 7440/8000, s_loss: 0.0016
# step: 7450/8000, s_loss: 0.0016
# step: 7460/8000, s_loss: 0.0016
# step: 7470/8000, s_loss: 0.0018
# step: 7480/8000, s_loss: 0.0016
# step: 7490/8000, s_loss: 0.0016
# step: 7500/8000, s_loss: 0.0016
# step: 7510/8000, s_loss: 0.0016
# step: 7520/8000, s_loss: 0.0016
# step: 7530/8000, s_loss: 0.0016
# step: 7540/8000, s_loss: 0.0016
# step: 7550/8000, s_loss: 0.0016
# step: 7560/8000, s_loss: 0.0016
# step: 7570/8000, s_loss: 0.0017
# step: 7580/8000, s_loss: 0.0016
# step: 7590/8000, s_loss: 0.0016
# step: 7600/8000, s_loss: 0.0015
# step: 7610/8000, s_loss: 0.0016
# step: 7620/8000, s_loss: 0.0016
# step: 7630/8000, s_loss: 0.0016
# step: 7640/8000, s_loss: 0.0016
# step: 7650/8000, s_loss: 0.0017
# step: 7660/8000, s_loss: 0.0016
# step: 7670/8000, s_loss: 0.0015
# step: 7680/8000, s_loss: 0.0015
# step: 7690/8000, s_loss: 0.0015
# step: 7700/8000, s_loss: 0.0015
# step: 7710/8000, s_loss: 0.0015
# step: 7720/8000, s_loss: 0.0015
# step: 7730/8000, s_loss: 0.0015
# step: 7740/8000, s_loss: 0.0017
# step: 7750/8000, s_loss: 0.0015
# step: 7760/8000, s_loss: 0.0016
# step: 7770/8000, s_loss: 0.0016
# step: 7780/8000, s_loss: 0.0015
# step: 7790/8000, s_loss: 0.0015
# step: 7800/8000, s_loss: 0.0015
# step: 7810/8000, s_loss: 0.0015
# step: 7820/8000, s_loss: 0.0015
# step: 7830/8000, s_loss: 0.0016
# step: 7840/8000, s_loss: 0.0015
# step: 7850/8000, s_loss: 0.0015
# step: 7860/8000, s_loss: 0.0015
# step: 7870/8000, s_loss: 0.0015
# step: 7880/8000, s_loss: 0.0016
# step: 7890/8000, s_loss: 0.0016
# step: 7900/8000, s_loss: 0.0016
# step: 7910/8000, s_loss: 0.0017
# step: 7920/8000, s_loss: 0.0015
# step: 7930/8000, s_loss: 0.0016
# step: 7940/8000, s_loss: 0.0015
# step: 7950/8000, s_loss: 0.0015
# step: 7960/8000, s_loss: 0.0015
# step: 7970/8000, s_loss: 0.0015
# step: 7980/8000, s_loss: 0.0015
# step: 7990/8000, s_loss: 0.0018
# Finish Training with Supervised Loss Only
# Start Joint Training
# step: 0/5000, d_loss: 2.0585, g_loss_u: 0.6821, g_loss_s: 0.0128, g_loss_v: 0.276, e_loss_t0: 0.0716
# step: 10/5000, d_loss: 1.9028, g_loss_u: 1.1364, g_loss_s: 0.0064, g_loss_v: 0.2413, e_loss_t0: 0.019
# step: 20/5000, d_loss: 1.897, g_loss_u: 1.1804, g_loss_s: 0.0032, g_loss_v: 0.2154, e_loss_t0: 0.0112
# step: 30/5000, d_loss: 1.8845, g_loss_u: 1.0144, g_loss_s: 0.0023, g_loss_v: 0.2127, e_loss_t0: 0.0039
# step: 40/5000, d_loss: 1.8714, g_loss_u: 1.0941, g_loss_s: 0.0021, g_loss_v: 0.1978, e_loss_t0: 0.0048
# step: 50/5000, d_loss: 1.8572, g_loss_u: 1.0578, g_loss_s: 0.0049, g_loss_v: 0.159, e_loss_t0: 0.0053
# step: 60/5000, d_loss: 1.8235, g_loss_u: 1.1261, g_loss_s: 0.0153, g_loss_v: 0.0629, e_loss_t0: 0.005
# step: 70/5000, d_loss: 1.6745, g_loss_u: 1.2458, g_loss_s: 0.0198, g_loss_v: 0.0411, e_loss_t0: 0.0049
# step: 80/5000, d_loss: 1.4289, g_loss_u: 1.5501, g_loss_s: 0.0149, g_loss_v: 0.0338, e_loss_t0: 0.0046
# step: 90/5000, d_loss: 1.4787, g_loss_u: 1.7182, g_loss_s: 0.009, g_loss_v: 0.0467, e_loss_t0: 0.0047
# step: 100/5000, d_loss: 1.3225, g_loss_u: 1.4423, g_loss_s: 0.0054, g_loss_v: 0.0283, e_loss_t0: 0.0047
# step: 110/5000, d_loss: 1.1025, g_loss_u: 1.4219, g_loss_s: 0.0031, g_loss_v: 0.0446, e_loss_t0: 0.0045
# step: 120/5000, d_loss: 1.0217, g_loss_u: 1.5469, g_loss_s: 0.0031, g_loss_v: 0.0307, e_loss_t0: 0.0046
# step: 130/5000, d_loss: 1.1096, g_loss_u: 1.7415, g_loss_s: 0.0023, g_loss_v: 0.027, e_loss_t0: 0.0046
# step: 140/5000, d_loss: 0.779, g_loss_u: 1.8863, g_loss_s: 0.0024, g_loss_v: 0.0269, e_loss_t0: 0.0045
# step: 150/5000, d_loss: 1.0172, g_loss_u: 2.1094, g_loss_s: 0.0025, g_loss_v: 0.0351, e_loss_t0: 0.0046
# step: 160/5000, d_loss: 0.8853, g_loss_u: 2.1785, g_loss_s: 0.0021, g_loss_v: 0.0307, e_loss_t0: 0.0045
# step: 170/5000, d_loss: 0.8213, g_loss_u: 2.2298, g_loss_s: 0.0022, g_loss_v: 0.0303, e_loss_t0: 0.0046
# step: 180/5000, d_loss: 1.3332, g_loss_u: 2.2057, g_loss_s: 0.0024, g_loss_v: 0.0327, e_loss_t0: 0.0045
# step: 190/5000, d_loss: 0.8208, g_loss_u: 2.0652, g_loss_s: 0.0021, g_loss_v: 0.0333, e_loss_t0: 0.0045
# step: 200/5000, d_loss: 1.0777, g_loss_u: 2.0752, g_loss_s: 0.0022, g_loss_v: 0.0302, e_loss_t0: 0.0045
# step: 210/5000, d_loss: 2.0663, g_loss_u: 1.8916, g_loss_s: 0.002, g_loss_v: 0.033, e_loss_t0: 0.0044
# step: 220/5000, d_loss: 1.7355, g_loss_u: 1.53, g_loss_s: 0.002, g_loss_v: 0.0311, e_loss_t0: 0.0045
# step: 230/5000, d_loss: 1.6012, g_loss_u: 1.3076, g_loss_s: 0.0019, g_loss_v: 0.0296, e_loss_t0: 0.0044
# step: 240/5000, d_loss: 1.1755, g_loss_u: 1.344, g_loss_s: 0.0023, g_loss_v: 0.0327, e_loss_t0: 0.0046
# step: 250/5000, d_loss: 0.8034, g_loss_u: 1.5901, g_loss_s: 0.0021, g_loss_v: 0.0288, e_loss_t0: 0.0042
# step: 260/5000, d_loss: 0.7772, g_loss_u: 1.8623, g_loss_s: 0.0047, g_loss_v: 0.0269, e_loss_t0: 0.0039
# step: 270/5000, d_loss: 0.9847, g_loss_u: 1.9821, g_loss_s: 0.0024, g_loss_v: 0.0401, e_loss_t0: 0.0038
# step: 280/5000, d_loss: 0.8008, g_loss_u: 2.0747, g_loss_s: 0.0019, g_loss_v: 0.0314, e_loss_t0: 0.0035
# step: 290/5000, d_loss: 0.6817, g_loss_u: 2.1458, g_loss_s: 0.002, g_loss_v: 0.03, e_loss_t0: 0.0036
# step: 300/5000, d_loss: 0.6063, g_loss_u: 2.2857, g_loss_s: 0.0022, g_loss_v: 0.0255, e_loss_t0: 0.0036
# step: 310/5000, d_loss: 0.5378, g_loss_u: 2.3965, g_loss_s: 0.0021, g_loss_v: 0.0277, e_loss_t0: 0.0035
# step: 320/5000, d_loss: 0.5461, g_loss_u: 2.5053, g_loss_s: 0.0023, g_loss_v: 0.0313, e_loss_t0: 0.0037
# step: 330/5000, d_loss: 0.5241, g_loss_u: 2.5918, g_loss_s: 0.0025, g_loss_v: 0.0286, e_loss_t0: 0.0034
# step: 340/5000, d_loss: 0.5051, g_loss_u: 2.6843, g_loss_s: 0.0033, g_loss_v: 0.0334, e_loss_t0: 0.0034
# step: 350/5000, d_loss: 6.3981, g_loss_u: 0.0601, g_loss_s: 0.0023, g_loss_v: 0.0284, e_loss_t0: 0.0037
# step: 360/5000, d_loss: 1.003, g_loss_u: 2.0791, g_loss_s: 0.0153, g_loss_v: 0.0318, e_loss_t0: 0.0035
# step: 370/5000, d_loss: 1.5364, g_loss_u: 1.7129, g_loss_s: 0.0035, g_loss_v: 0.0267, e_loss_t0: 0.0034
# step: 380/5000, d_loss: 1.5719, g_loss_u: 1.5251, g_loss_s: 0.0025, g_loss_v: 0.0287, e_loss_t0: 0.0034
# step: 390/5000, d_loss: 3.8706, g_loss_u: 0.2365, g_loss_s: 0.0023, g_loss_v: 0.0323, e_loss_t0: 0.0033
# step: 400/5000, d_loss: 2.6036, g_loss_u: 0.4442, g_loss_s: 0.0024, g_loss_v: 0.0291, e_loss_t0: 0.0034
# step: 410/5000, d_loss: 1.4973, g_loss_u: 1.2107, g_loss_s: 0.0021, g_loss_v: 0.0308, e_loss_t0: 0.0033
# step: 420/5000, d_loss: 1.8399, g_loss_u: 1.0511, g_loss_s: 0.0023, g_loss_v: 0.0322, e_loss_t0: 0.0034
# step: 430/5000, d_loss: 2.0252, g_loss_u: 0.7929, g_loss_s: 0.0023, g_loss_v: 0.0341, e_loss_t0: 0.0034
# step: 440/5000, d_loss: 1.9382, g_loss_u: 0.907, g_loss_s: 0.002, g_loss_v: 0.0318, e_loss_t0: 0.0033
# step: 450/5000, d_loss: 1.8378, g_loss_u: 1.0851, g_loss_s: 0.0021, g_loss_v: 0.0258, e_loss_t0: 0.0032
# step: 460/5000, d_loss: 1.5745, g_loss_u: 1.3764, g_loss_s: 0.002, g_loss_v: 0.0286, e_loss_t0: 0.0032
# step: 470/5000, d_loss: 1.3508, g_loss_u: 1.6552, g_loss_s: 0.0022, g_loss_v: 0.0301, e_loss_t0: 0.0035
# step: 480/5000, d_loss: 1.2004, g_loss_u: 1.8724, g_loss_s: 0.002, g_loss_v: 0.0268, e_loss_t0: 0.0032
# step: 490/5000, d_loss: 1.033, g_loss_u: 2.0695, g_loss_s: 0.0023, g_loss_v: 0.0268, e_loss_t0: 0.0033
# step: 500/5000, d_loss: 1.1359, g_loss_u: 2.1811, g_loss_s: 0.0025, g_loss_v: 0.0271, e_loss_t0: 0.0033
# step: 510/5000, d_loss: 0.9939, g_loss_u: 2.105, g_loss_s: 0.0021, g_loss_v: 0.0256, e_loss_t0: 0.0033
# step: 520/5000, d_loss: 1.2504, g_loss_u: 2.2141, g_loss_s: 0.0024, g_loss_v: 0.0283, e_loss_t0: 0.0032
# step: 530/5000, d_loss: 1.0239, g_loss_u: 1.9615, g_loss_s: 0.0024, g_loss_v: 0.0258, e_loss_t0: 0.0034
# step: 540/5000, d_loss: 0.9507, g_loss_u: 1.998, g_loss_s: 0.0031, g_loss_v: 0.0258, e_loss_t0: 0.0033
# step: 550/5000, d_loss: 1.6485, g_loss_u: 2.2733, g_loss_s: 0.0023, g_loss_v: 0.0265, e_loss_t0: 0.0033
# ...
# step: 3810/5000, d_loss: 0.7152, g_loss_u: 2.5958, g_loss_s: 0.0033, g_loss_v: 0.0224, e_loss_t0: 0.0023
# step: 3820/5000, d_loss: 0.6531, g_loss_u: 2.7921, g_loss_s: 0.0047, g_loss_v: 0.0523, e_loss_t0: 0.0022
# step: 3830/5000, d_loss: 0.6286, g_loss_u: 2.8831, g_loss_s: 0.0045, g_loss_v: 0.0663, e_loss_t0: 0.0024
# step: 3840/5000, d_loss: 0.6208, g_loss_u: 2.9262, g_loss_s: 0.0039, g_loss_v: 0.0156, e_loss_t0: 0.0023
# step: 3850/5000, d_loss: 0.5601, g_loss_u: 2.903, g_loss_s: 0.0034, g_loss_v: 0.0247, e_loss_t0: 0.0022
# step: 3860/5000, d_loss: 0.5722, g_loss_u: 2.9099, g_loss_s: 0.0066, g_loss_v: 0.0197, e_loss_t0: 0.0023
# step: 3870/5000, d_loss: 0.5346, g_loss_u: 2.8566, g_loss_s: 0.0066, g_loss_v: 0.0688, e_loss_t0: 0.0023
# step: 3880/5000, d_loss: 0.5683, g_loss_u: 2.9986, g_loss_s: 0.007, g_loss_v: 0.0209, e_loss_t0: 0.0023
# step: 3890/5000, d_loss: 0.5068, g_loss_u: 2.9427, g_loss_s: 0.0068, g_loss_v: 0.0332, e_loss_t0: 0.0023
# step: 3900/5000, d_loss: 0.5515, g_loss_u: 3.0451, g_loss_s: 0.0059, g_loss_v: 0.0311, e_loss_t0: 0.0022
# step: 3910/5000, d_loss: 0.5092, g_loss_u: 3.0155, g_loss_s: 0.0047, g_loss_v: 0.0173, e_loss_t0: 0.0023
# step: 3920/5000, d_loss: 0.5072, g_loss_u: 3.0597, g_loss_s: 0.006, g_loss_v: 0.0312, e_loss_t0: 0.0023
# step: 3930/5000, d_loss: 0.5358, g_loss_u: 3.0737, g_loss_s: 0.0086, g_loss_v: 0.0522, e_loss_t0: 0.0022
# step: 3940/5000, d_loss: 0.4961, g_loss_u: 2.9788, g_loss_s: 0.0048, g_loss_v: 0.03, e_loss_t0: 0.0024
# step: 3950/5000, d_loss: 0.5318, g_loss_u: 2.981, g_loss_s: 0.0129, g_loss_v: 0.0149, e_loss_t0: 0.0023
# step: 3960/5000, d_loss: 0.4984, g_loss_u: 3.0629, g_loss_s: 0.012, g_loss_v: 0.0233, e_loss_t0: 0.0022
# step: 3970/5000, d_loss: 0.5133, g_loss_u: 3.0113, g_loss_s: 0.0051, g_loss_v: 0.013, e_loss_t0: 0.0022
# step: 3980/5000, d_loss: 0.5314, g_loss_u: 3.0572, g_loss_s: 0.0062, g_loss_v: 0.0245, e_loss_t0: 0.0023
# step: 3990/5000, d_loss: 0.5057, g_loss_u: 3.1746, g_loss_s: 0.0082, g_loss_v: 0.05, e_loss_t0: 0.0023
# step: 4000/5000, d_loss: 0.4663, g_loss_u: 3.168, g_loss_s: 0.0065, g_loss_v: 0.0205, e_loss_t0: 0.0022
# step: 4010/5000, d_loss: 0.4765, g_loss_u: 3.0992, g_loss_s: 0.0044, g_loss_v: 0.0255, e_loss_t0: 0.0023
# step: 4020/5000, d_loss: 0.514, g_loss_u: 3.2174, g_loss_s: 0.0039, g_loss_v: 0.039, e_loss_t0: 0.0022
# step: 4030/5000, d_loss: 0.501, g_loss_u: 3.166, g_loss_s: 0.0054, g_loss_v: 0.0145, e_loss_t0: 0.0023
# step: 4040/5000, d_loss: 0.4994, g_loss_u: 3.0485, g_loss_s: 0.0086, g_loss_v: 0.0622, e_loss_t0: 0.0024
# step: 4050/5000, d_loss: 0.4907, g_loss_u: 3.2448, g_loss_s: 0.0039, g_loss_v: 0.0132, e_loss_t0: 0.0023
# step: 4060/5000, d_loss: 0.4444, g_loss_u: 3.2785, g_loss_s: 0.0059, g_loss_v: 0.0182, e_loss_t0: 0.0024
# step: 4070/5000, d_loss: 0.4826, g_loss_u: 3.0644, g_loss_s: 0.0043, g_loss_v: 0.034, e_loss_t0: 0.0023
# step: 4080/5000, d_loss: 0.4829, g_loss_u: 3.1865, g_loss_s: 0.0048, g_loss_v: 0.0324, e_loss_t0: 0.0021
# step: 4090/5000, d_loss: 0.4647, g_loss_u: 3.2218, g_loss_s: 0.0055, g_loss_v: 0.0185, e_loss_t0: 0.0023
# step: 4100/5000, d_loss: 0.4692, g_loss_u: 3.2565, g_loss_s: 0.0065, g_loss_v: 0.0122, e_loss_t0: 0.0023
# step: 4110/5000, d_loss: 0.4887, g_loss_u: 3.294, g_loss_s: 0.0042, g_loss_v: 0.0338, e_loss_t0: 0.0023
# step: 4120/5000, d_loss: 0.4727, g_loss_u: 3.1975, g_loss_s: 0.0039, g_loss_v: 0.0456, e_loss_t0: 0.0023
# step: 4130/5000, d_loss: 0.4747, g_loss_u: 3.2212, g_loss_s: 0.004, g_loss_v: 0.0168, e_loss_t0: 0.0023
# step: 4140/5000, d_loss: 0.4533, g_loss_u: 3.2635, g_loss_s: 0.0057, g_loss_v: 0.0315, e_loss_t0: 0.0024
# step: 4150/5000, d_loss: 0.4651, g_loss_u: 3.3068, g_loss_s: 0.0035, g_loss_v: 0.0153, e_loss_t0: 0.0024
# step: 4160/5000, d_loss: 0.4573, g_loss_u: 3.1962, g_loss_s: 0.0051, g_loss_v: 0.0123, e_loss_t0: 0.0022
# step: 4170/5000, d_loss: 0.4726, g_loss_u: 3.3431, g_loss_s: 0.0067, g_loss_v: 0.0303, e_loss_t0: 0.0023
# step: 4180/5000, d_loss: 0.4574, g_loss_u: 3.215, g_loss_s: 0.005, g_loss_v: 0.0286, e_loss_t0: 0.0023
# step: 4190/5000, d_loss: 0.4751, g_loss_u: 3.2383, g_loss_s: 0.0038, g_loss_v: 0.0094, e_loss_t0: 0.0022
# step: 4200/5000, d_loss: 0.4418, g_loss_u: 3.2959, g_loss_s: 0.0127, g_loss_v: 0.0317, e_loss_t0: 0.0023
# step: 4210/5000, d_loss: 0.4608, g_loss_u: 3.3425, g_loss_s: 0.0048, g_loss_v: 0.0102, e_loss_t0: 0.0022
# step: 4220/5000, d_loss: 0.4376, g_loss_u: 3.2267, g_loss_s: 0.0072, g_loss_v: 0.0315, e_loss_t0: 0.0022
# step: 4230/5000, d_loss: 0.4293, g_loss_u: 3.2041, g_loss_s: 0.0053, g_loss_v: 0.044, e_loss_t0: 0.0022
# step: 4240/5000, d_loss: 0.8766, g_loss_u: 3.7576, g_loss_s: 0.0048, g_loss_v: 0.0257, e_loss_t0: 0.0022
# step: 4250/5000, d_loss: 0.668, g_loss_u: 2.9562, g_loss_s: 0.0083, g_loss_v: 0.043, e_loss_t0: 0.0022
# step: 4260/5000, d_loss: 0.6286, g_loss_u: 2.8141, g_loss_s: 0.0042, g_loss_v: 0.018, e_loss_t0: 0.0022
# step: 4270/5000, d_loss: 0.5625, g_loss_u: 2.9123, g_loss_s: 0.0085, g_loss_v: 0.022, e_loss_t0: 0.0023
# step: 4280/5000, d_loss: 0.5537, g_loss_u: 2.9374, g_loss_s: 0.0033, g_loss_v: 0.0247, e_loss_t0: 0.0021
# step: 4290/5000, d_loss: 0.5757, g_loss_u: 2.8887, g_loss_s: 0.0068, g_loss_v: 0.0303, e_loss_t0: 0.0022
# step: 4300/5000, d_loss: 0.5241, g_loss_u: 2.914, g_loss_s: 0.0083, g_loss_v: 0.0535, e_loss_t0: 0.0022
# step: 4310/5000, d_loss: 0.5072, g_loss_u: 2.8726, g_loss_s: 0.0039, g_loss_v: 0.0143, e_loss_t0: 0.0022
# step: 4320/5000, d_loss: 0.4838, g_loss_u: 2.8439, g_loss_s: 0.0101, g_loss_v: 0.048, e_loss_t0: 0.0022
# step: 4330/5000, d_loss: 0.5024, g_loss_u: 2.9221, g_loss_s: 0.0042, g_loss_v: 0.0177, e_loss_t0: 0.0023
# step: 4340/5000, d_loss: 0.4678, g_loss_u: 2.9337, g_loss_s: 0.0039, g_loss_v: 0.0415, e_loss_t0: 0.0022
# step: 4350/5000, d_loss: 0.4729, g_loss_u: 2.9161, g_loss_s: 0.0075, g_loss_v: 0.0401, e_loss_t0: 0.0022
# step: 4360/5000, d_loss: 0.4482, g_loss_u: 3.0278, g_loss_s: 0.0052, g_loss_v: 0.0241, e_loss_t0: 0.0022
# step: 4370/5000, d_loss: 0.4471, g_loss_u: 3.058, g_loss_s: 0.0042, g_loss_v: 0.0131, e_loss_t0: 0.0023
# step: 4380/5000, d_loss: 0.4425, g_loss_u: 3.0894, g_loss_s: 0.0041, g_loss_v: 0.0141, e_loss_t0: 0.0022
# step: 4390/5000, d_loss: 0.4076, g_loss_u: 3.0727, g_loss_s: 0.0034, g_loss_v: 0.0328, e_loss_t0: 0.0022
# step: 4400/5000, d_loss: 0.4415, g_loss_u: 3.1803, g_loss_s: 0.0076, g_loss_v: 0.011, e_loss_t0: 0.0022
# step: 4410/5000, d_loss: 0.4521, g_loss_u: 3.15, g_loss_s: 0.006, g_loss_v: 0.0232, e_loss_t0: 0.0022
# step: 4420/5000, d_loss: 0.39, g_loss_u: 3.2672, g_loss_s: 0.0048, g_loss_v: 0.0094, e_loss_t0: 0.0022
# step: 4430/5000, d_loss: 0.4213, g_loss_u: 3.3166, g_loss_s: 0.0051, g_loss_v: 0.0314, e_loss_t0: 0.0022
# step: 4440/5000, d_loss: 0.4452, g_loss_u: 3.205, g_loss_s: 0.0041, g_loss_v: 0.0412, e_loss_t0: 0.0022
# step: 4450/5000, d_loss: 0.4117, g_loss_u: 3.3854, g_loss_s: 0.0054, g_loss_v: 0.0158, e_loss_t0: 0.0022
# step: 4460/5000, d_loss: 0.3621, g_loss_u: 3.4056, g_loss_s: 0.0045, g_loss_v: 0.0322, e_loss_t0: 0.0023
# step: 4470/5000, d_loss: 0.4026, g_loss_u: 3.4255, g_loss_s: 0.0033, g_loss_v: 0.0144, e_loss_t0: 0.0022
# step: 4480/5000, d_loss: 0.389, g_loss_u: 3.4595, g_loss_s: 0.0037, g_loss_v: 0.0245, e_loss_t0: 0.0021
# step: 4490/5000, d_loss: 0.3722, g_loss_u: 3.5434, g_loss_s: 0.0038, g_loss_v: 0.0124, e_loss_t0: 0.0022
# step: 4500/5000, d_loss: 0.4424, g_loss_u: 3.3631, g_loss_s: 0.0115, g_loss_v: 0.0185, e_loss_t0: 0.0021
# step: 4510/5000, d_loss: 0.4053, g_loss_u: 3.3388, g_loss_s: 0.0059, g_loss_v: 0.0805, e_loss_t0: 0.0021
# step: 4520/5000, d_loss: 0.3647, g_loss_u: 3.4547, g_loss_s: 0.0045, g_loss_v: 0.0437, e_loss_t0: 0.0022
# step: 4530/5000, d_loss: 0.3636, g_loss_u: 3.4722, g_loss_s: 0.0064, g_loss_v: 0.0152, e_loss_t0: 0.0023
# step: 4540/5000, d_loss: 0.3477, g_loss_u: 3.5776, g_loss_s: 0.0043, g_loss_v: 0.0146, e_loss_t0: 0.0023
# step: 4550/5000, d_loss: 0.3393, g_loss_u: 3.5523, g_loss_s: 0.0033, g_loss_v: 0.0133, e_loss_t0: 0.0024
# step: 4560/5000, d_loss: 0.3414, g_loss_u: 3.5392, g_loss_s: 0.004, g_loss_v: 0.0299, e_loss_t0: 0.0022
# step: 4570/5000, d_loss: 0.3579, g_loss_u: 3.4974, g_loss_s: 0.0114, g_loss_v: 0.0596, e_loss_t0: 0.0021
# step: 4580/5000, d_loss: 0.4572, g_loss_u: 3.6291, g_loss_s: 0.0079, g_loss_v: 0.0228, e_loss_t0: 0.0022
# step: 4590/5000, d_loss: 0.4306, g_loss_u: 3.3071, g_loss_s: 0.0072, g_loss_v: 0.0434, e_loss_t0: 0.0023
# step: 4600/5000, d_loss: 0.4091, g_loss_u: 3.4031, g_loss_s: 0.0038, g_loss_v: 0.0145, e_loss_t0: 0.0022
# step: 4610/5000, d_loss: 0.3926, g_loss_u: 3.3457, g_loss_s: 0.0036, g_loss_v: 0.0106, e_loss_t0: 0.0022
# step: 4620/5000, d_loss: 0.4151, g_loss_u: 3.278, g_loss_s: 0.0033, g_loss_v: 0.0412, e_loss_t0: 0.0021
# step: 4630/5000, d_loss: 0.3845, g_loss_u: 3.5481, g_loss_s: 0.0036, g_loss_v: 0.0138, e_loss_t0: 0.0022
# step: 4640/5000, d_loss: 0.3555, g_loss_u: 3.6263, g_loss_s: 0.0039, g_loss_v: 0.0265, e_loss_t0: 0.0021
# step: 4650/5000, d_loss: 0.3602, g_loss_u: 3.5061, g_loss_s: 0.0031, g_loss_v: 0.0135, e_loss_t0: 0.0022
# step: 4660/5000, d_loss: 0.3849, g_loss_u: 3.5555, g_loss_s: 0.0041, g_loss_v: 0.0165, e_loss_t0: 0.0023
# step: 4670/5000, d_loss: 0.3698, g_loss_u: 3.7602, g_loss_s: 0.0031, g_loss_v: 0.0086, e_loss_t0: 0.0022
# step: 4680/5000, d_loss: 0.321, g_loss_u: 3.6828, g_loss_s: 0.004, g_loss_v: 0.0199, e_loss_t0: 0.0022
# step: 4690/5000, d_loss: 0.3116, g_loss_u: 3.7147, g_loss_s: 0.0049, g_loss_v: 0.0206, e_loss_t0: 0.002
# step: 4700/5000, d_loss: 0.3623, g_loss_u: 3.8125, g_loss_s: 0.0062, g_loss_v: 0.0158, e_loss_t0: 0.0022
# step: 4710/5000, d_loss: 0.3233, g_loss_u: 3.7234, g_loss_s: 0.0032, g_loss_v: 0.0218, e_loss_t0: 0.0021
# step: 4720/5000, d_loss: 0.3243, g_loss_u: 3.7169, g_loss_s: 0.0044, g_loss_v: 0.0201, e_loss_t0: 0.0021
# step: 4730/5000, d_loss: 0.3357, g_loss_u: 3.6816, g_loss_s: 0.0042, g_loss_v: 0.0303, e_loss_t0: 0.0022
# step: 4740/5000, d_loss: 0.3286, g_loss_u: 3.6652, g_loss_s: 0.0051, g_loss_v: 0.0283, e_loss_t0: 0.0021
# step: 4750/5000, d_loss: 0.3267, g_loss_u: 3.8062, g_loss_s: 0.0034, g_loss_v: 0.0085, e_loss_t0: 0.0021
# step: 4760/5000, d_loss: 0.3242, g_loss_u: 3.7398, g_loss_s: 0.004, g_loss_v: 0.0223, e_loss_t0: 0.0022
# step: 4770/5000, d_loss: 0.3383, g_loss_u: 3.7579, g_loss_s: 0.0039, g_loss_v: 0.0339, e_loss_t0: 0.0022
# step: 4780/5000, d_loss: 0.2917, g_loss_u: 3.842, g_loss_s: 0.0032, g_loss_v: 0.0201, e_loss_t0: 0.0021
# step: 4790/5000, d_loss: 0.3084, g_loss_u: 3.6821, g_loss_s: 0.0043, g_loss_v: 0.0654, e_loss_t0: 0.0021
# step: 4800/5000, d_loss: 0.3142, g_loss_u: 3.83, g_loss_s: 0.0035, g_loss_v: 0.0279, e_loss_t0: 0.0022
# step: 4810/5000, d_loss: 0.3065, g_loss_u: 3.9243, g_loss_s: 0.0053, g_loss_v: 0.0324, e_loss_t0: 0.0023
# step: 4820/5000, d_loss: 0.3179, g_loss_u: 3.786, g_loss_s: 0.0051, g_loss_v: 0.0505, e_loss_t0: 0.0022
# step: 4830/5000, d_loss: 0.3119, g_loss_u: 3.9567, g_loss_s: 0.005, g_loss_v: 0.0243, e_loss_t0: 0.0021
# step: 4840/5000, d_loss: 0.3023, g_loss_u: 3.9368, g_loss_s: 0.0037, g_loss_v: 0.0125, e_loss_t0: 0.0021
# step: 4850/5000, d_loss: 0.3535, g_loss_u: 3.8932, g_loss_s: 0.0058, g_loss_v: 0.0367, e_loss_t0: 0.0021
# step: 4860/5000, d_loss: 0.3736, g_loss_u: 4.0179, g_loss_s: 0.0043, g_loss_v: 0.017, e_loss_t0: 0.0022
# step: 4870/5000, d_loss: 0.2897, g_loss_u: 4.0748, g_loss_s: 0.0044, g_loss_v: 0.0446, e_loss_t0: 0.0022
# step: 4880/5000, d_loss: 0.2788, g_loss_u: 3.9119, g_loss_s: 0.0033, g_loss_v: 0.0151, e_loss_t0: 0.0021
# step: 4890/5000, d_loss: 0.2884, g_loss_u: 4.0236, g_loss_s: 0.0037, g_loss_v: 0.0146, e_loss_t0: 0.0021
# step: 4900/5000, d_loss: 0.2985, g_loss_u: 4.0395, g_loss_s: 0.007, g_loss_v: 0.0134, e_loss_t0: 0.0022
# step: 4910/5000, d_loss: 0.3173, g_loss_u: 4.0876, g_loss_s: 0.0049, g_loss_v: 0.0206, e_loss_t0: 0.0021
# step: 4920/5000, d_loss: 0.3097, g_loss_u: 4.1444, g_loss_s: 0.0054, g_loss_v: 0.0325, e_loss_t0: 0.0022
# step: 4930/5000, d_loss: 0.3383, g_loss_u: 3.8536, g_loss_s: 0.0051, g_loss_v: 0.0325, e_loss_t0: 0.0022
# step: 4940/5000, d_loss: 0.3095, g_loss_u: 3.9327, g_loss_s: 0.0063, g_loss_v: 0.0378, e_loss_t0: 0.0022
# step: 4950/5000, d_loss: 0.3133, g_loss_u: 4.108, g_loss_s: 0.0112, g_loss_v: 0.0198, e_loss_t0: 0.0022
# step: 4960/5000, d_loss: 0.357, g_loss_u: 3.8597, g_loss_s: 0.0059, g_loss_v: 0.0186, e_loss_t0: 0.0021
# step: 4970/5000, d_loss: 0.3073, g_loss_u: 3.9224, g_loss_s: 0.0044, g_loss_v: 0.0213, e_loss_t0: 0.0023
# step: 4980/5000, d_loss: 0.3199, g_loss_u: 3.9832, g_loss_s: 0.0037, g_loss_v: 0.013, e_loss_t0: 0.0021
# step: 4990/5000, d_loss: 0.304, g_loss_u: 4.1406, g_loss_s: 0.0052, g_loss_v: 0.0301, e_loss_t0: 0.0021
# Finish Joint Training
# Finish Synthetic Data Generation
# WARNING:tensorflow:From C:\Users\Admin\Documents\WeChat Files\wxid_epckp5jbazzj22\FileStorage\File\2024-05\TimeGAN\TimeGAN\metrics\discriminative_metrics.py:81: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# Discriminative score: 0.2345
# WARNING:tensorflow:From C:\Users\Admin\Documents\WeChat Files\wxid_epckp5jbazzj22\FileStorage\File\2024-05\TimeGAN\TimeGAN\metrics\predictive_metrics.py:81: The name tf.losses.absolute_difference is deprecated. Please use tf.compat.v1.losses.absolute_difference instead.
#
# Predictive score: 0.4893
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 284 samples in 0.005s...
# [t-SNE] Computed neighbors for 284 samples in 0.056s...
# [t-SNE] Computed conditional probabilities for sample 284 / 284
# [t-SNE] Mean sigma: 0.000000
# C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\sklearn\neighbors\base.py:441: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   old_joblib = LooseVersion(joblib_version) < LooseVersion('0.12')
# C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\sklearn\neighbors\base.py:441: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   old_joblib = LooseVersion(joblib_version) < LooseVersion('0.12')
# C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\sklearn\manifold\t_sne.py:344: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   error = np.finfo(np.float).max
# C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\sklearn\manifold\t_sne.py:345: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   best_error = np.finfo(np.float).max
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 58.093491
# [t-SNE] KL divergence after 300 iterations: 0.488574
# C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\sklearn\manifold\t_sne.py:344: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   error = np.finfo(np.float).max
# C:\Users\Admin\anaconda3\envs\gan\lib\site-packages\sklearn\manifold\t_sne.py:345: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   best_error = np.finfo(np.float).max

# %% [markdown]
# ## Evaluate the generated data
#
# ### 1. Discriminative score
#
# To evaluate the classification accuracy between original and synthetic data using post-hoc RNN network. The output is |classification accuracy - 0.5|.
#
# - metric_iteration: the number of iterations for metric computation.

# %%
metric_iteration = 5

discriminative_score = list()
for _ in range(metric_iteration):
  temp_disc = discriminative_score_metrics(ori_data, generated_data)
  discriminative_score.append(temp_disc)

print('Discriminative score: ' + str(np.round(np.mean(discriminative_score), 4)))
# Out:
# Discriminative score: 0.2448

# %% [markdown]
# ## Evaluate the generated data
#
# ### 2. Predictive score
#
# To evaluate the prediction performance on train on synthetic, test on real setting. More specifically, we use Post-hoc RNN architecture to predict one-step ahead and report the performance in terms of MAE.

# %%
predictive_score = list()
for tt in range(metric_iteration):
  temp_pred = predictive_score_metrics(ori_data, generated_data)
  predictive_score.append(temp_pred)   
    
print('Predictive score: ' + str(np.round(np.mean(predictive_score), 4)))

# %% [markdown]
# ## Evaluate the generated data
#
# ### 3. Visualization
#
# We visualize the original and synthetic data distributions using PCA and tSNE analysis.

# %%
visualization(ori_data, generated_data, 'pca')
visualization(ori_data, generated_data, 'tsne')
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 2000 samples in 0.001s...
# [t-SNE] Computed neighbors for 2000 samples in 0.075s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2000
# [t-SNE] Computed conditional probabilities for sample 2000 / 2000
# [t-SNE] Mean sigma: 0.031771
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 54.970322
# [t-SNE] KL divergence after 300 iterations: 0.729995
